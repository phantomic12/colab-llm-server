# %% [markdown]
# # 00 — Setup: Install llama-cpp-python with CUDA & Verify the T4 GPU
#
# This notebook installs `llama-cpp-python` with **CUDA 12.4** support and confirms that the Colab runtime has a T4 GPU attached.
#
# **Requirements:** Runtime → Change runtime type → **T4 GPU** (free tier).

# %% [markdown]
# ## 1. Check the GPU

# %%
# !nvidia-smi

import torch
print(f"\nPyTorch CUDA available: {torch.cuda.is_available()}")
print(f"Device: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU only'}")
if torch.cuda.is_available():
    props = torch.cuda.get_device_properties(0)
    print(f"Total VRAM: {props.total_mem / 1024**2:.0f} MiB")

# %% [markdown]
# You should see a **Tesla T4** with ~15360 MiB total memory.

# %% [markdown]
# ## 2. Install llama-cpp-python with CUDA 12.4

# %%
# %%time
# %%capture
pip install llama-cpp-python huggingface_hub --extra-index-url https://abetlen.github.io/llama-cpp-python/whl/cu124

# %% [markdown]
# ## 3. Verify the install

# %%
import llama_cpp
print(f"llama-cpp-python version: {llama_cpp.__version__}")

# Quick smoke test: check that the shared library loaded and CUDA is wired up
from llama_cpp import Llama
print("Llama class imported OK — CUDA build active ✅")

# %% [markdown]
# ## 4. Install huggingface_hub and verify

# %%
from huggingface_hub import hf_hub_download
print("huggingface_hub ready ✅")

# %% [markdown]
# ## ✅ Setup complete
#
# You now have a CUDA-enabled `llama-cpp-python` install on a T4 GPU. Proceed to any model notebook.
